# %% [markdown]
# Importo las librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Cargo los datos

# %%
# cargo los datos

df = pd.read_csv('C:/Users/AnaGu/Downloads/Crime_Data_from_2020_to_Present.csv')
df.info
# Out:
# <bound method DataFrame.info of              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240
# 3        210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830
# ...            ...                     ...                     ...       ...
# 1004984  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130
# 1004985  250404100  02/18/2025 12:00:00 AM  02/18/2025 12:00:00 AM      1000
# 1004986  251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM      1554
# 1004987  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1600
# 1004988  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235
#
# ...

# %%
df.value_counts()
# Out:
# DR_NO      Date Rptd               DATE OCC                TIME OCC  AREA  AREA NAME   Rpt Dist No  Part 1-2  Crm Cd  Crm Cd Desc                                              Mocodes                                            Vict Age  Vict Sex  Vict Descent  Premis Cd  Premis Desc               Weapon Used Cd  Weapon Desc                                     Status  Status Desc   Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  LOCATION                         Cross Street                     LAT      LON
# ...

# %% [markdown]
# Visualizo la tabla de crímenes

# %%
df
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845
# 1        201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845
# 2        240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240
# 3        210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310
# 4        201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830
# ...            ...                     ...                     ...       ...
# 1004984  252104112  02/02/2025 12:00:00 AM  02/02/2025 12:00:00 AM       130
# 1004985  250404100  02/18/2025 12:00:00 AM  02/18/2025 12:00:00 AM      1000
# 1004986  251304095  01/31/2025 12:00:00 AM  01/30/2025 12:00:00 AM      1554
# 1004987  251704066  01/17/2025 12:00:00 AM  01/17/2025 12:00:00 AM      1600
# 1004988  251904210  03/25/2025 12:00:00 AM  03/25/2025 12:00:00 AM      1235
#
# ...

# %%
df = df.drop(['DR_NO', 'Weapon Used Cd'], axis = 1)

# %% [markdown]
# Miro cuántos valores distintos tengo en las columnas y si hay muchos NaN.

# %%
df.value_counts()
# Out:
# Date Rptd               DATE OCC                TIME OCC  AREA  AREA NAME   Rpt Dist No  Part 1-2  Crm Cd  Crm Cd Desc                                              Mocodes                                            Vict Age  Vict Sex  Vict Descent  Premis Cd  Premis Desc               Weapon Desc                                     Status  Status Desc   Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  LOCATION                         Cross Street                     LAT      LON
# 01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM  2135      19    Mission     1924         1         761     BRANDISH WEAPON                                          1822 3006 3028 3039 3032 3037 3101 4019 3602       41        M         H             101.0      STREET                    KNIFE WITH BLADE 6INCHES OR LESS                AA      Adult Arrest  761.0     930.0     997.0     998.0     ASTORIA                      ST  SAN FERNANDO                 RD  34.2949  -118.4571    1
# ...

# %% [markdown]
# Podría elimianr algunas columnas que no me interesan, como 'DR_NO' que es el número de caso y el código de arma, pero mejor hago una copia del original y voy trabajando con lo que me interesa.

# %%
df_copy = df.copy()
df_copy = df_copy[['DATE OCC', 'TIME OCC', 'Crm Cd Desc', 'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Desc', 'Weapon Desc', 'LOCATION', 'LAT', 'LON']]
df_copy
# Out:
#                        DATE OCC  TIME OCC  \
# 0        11/07/2020 12:00:00 AM       845
# 1        10/18/2020 12:00:00 AM      1845
# 2        10/30/2020 12:00:00 AM      1240
# 3        12/24/2020 12:00:00 AM      1310
# 4        09/29/2020 12:00:00 AM      1830
# ...                         ...       ...
# 1004984  02/02/2025 12:00:00 AM       130
# 1004985  02/18/2025 12:00:00 AM      1000
# 1004986  01/30/2025 12:00:00 AM      1554
# 1004987  01/17/2025 12:00:00 AM      1600
# 1004988  03/25/2025 12:00:00 AM      1235
#
#                                                Crm Cd Desc  Vict Age Vict Sex  \
# 0                                        THEFT OF IDENTITY        31        M
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32        M
# 2                                        THEFT OF IDENTITY        30        M
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        47        F
# ...

# %% [markdown]
# #### Descent Code ('Vict Descent'):
# A - Other Asian
# B - Black
# C - Chinese
# D - Cambodian
# F - Filipino
# G - Guamanian
# H - Hispanic/Latin/Mexican
# I - American Indian/Alaskan Native
# J - Japanese
# K - Korean
# L - Laotian
# O - Other
# P - Pacific Islander
# S - Samoan
# U - Hawaiian
# V - Vietnamese
# W - White
# X - Unknown
# Z - Asian Indian

# %% [markdown]
# Voy a calcular el porcentaje de NaN por columna por si tengo que modificarlas.

# %%
def calcular_nan(df):
  total_filas = len(df)
  nan_por_columna = df.isnull().sum()
  porcentaje_nan = (nan_por_columna / total_filas) * 100
  return porcentaje_nan

df_nan = calcular_nan(df_copy)
print(df_nan)
# Out:
# DATE OCC         0.000000
# TIME OCC         0.000000
# Crm Cd Desc      0.000000
# Vict Age         0.000000
# Vict Sex        14.392595
# Vict Descent    14.393789
# Premis Desc      0.058508
# Weapon Desc     67.437753
# LOCATION         0.000000
# LAT              0.000000
# LON              0.000000
# dtype: float64

# %% [markdown]
# Veo que voy a tener que eliminar la columna de 'Weapon Desc' porque hay demasiados NaN.

# %%
df_copy = df_copy.drop('Weapon Desc', axis = 1)
df_copy
# Out:
#                        DATE OCC  TIME OCC  \
# 0        11/07/2020 12:00:00 AM       845
# 1        10/18/2020 12:00:00 AM      1845
# 2        10/30/2020 12:00:00 AM      1240
# 3        12/24/2020 12:00:00 AM      1310
# 4        09/29/2020 12:00:00 AM      1830
# ...                         ...       ...
# 1004984  02/02/2025 12:00:00 AM       130
# 1004985  02/18/2025 12:00:00 AM      1000
# 1004986  01/30/2025 12:00:00 AM      1554
# 1004987  01/17/2025 12:00:00 AM      1600
# 1004988  03/25/2025 12:00:00 AM      1235
#
#                                                Crm Cd Desc  Vict Age Vict Sex  \
# 0                                        THEFT OF IDENTITY        31        M
# 1           ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        32        M
# 2                                        THEFT OF IDENTITY        30        M
# 3        THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        47        F
# ...

# %% [markdown]
# Miro las edades de las víctimas.

# %%
df_copy['Vict Age'].value_counts()
# Out:
# Vict Age
#  0      269221
#  30      22289
#  35      21836
#  31      21420
#  29      21345
#          ...
#  98         71
# -2          28
# -3           6
# -4           3
#  120         1
# Name: count, Length: 104, dtype: int64

# %% [markdown]
# Veo que hay valores erróneos, como los negativos, 0 y el 120. Tengo que eliminarlos.
# Tengo que hacer una máscara booleana.

# %%
#
#



ARREGLAR ESTO QUITANDO LOS QUE ME SOBRAN



#

mask_age = (df_copy['Vict Age'] != 0)
df_copy = df_copy[mask_age]
df_copy['Vict Age'].value_counts()
# Out:
# Vict Age
#  30     22289
#  35     21836
#  31     21420
#  29     21345
#  28     20969
#         ...
#  98        71
# -2         28
# -3          6
# -4          3
#  120        1
# Name: count, Length: 103, dtype: int64

# %% [markdown]
# Calculo la media de esas edades.
